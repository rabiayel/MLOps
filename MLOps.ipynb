# %% [markdown]
# # MLOps

# %% [markdown]
# Bu derste eğittiğimiz makine öğrenmesi modellerini kaydedip bir websitesinden veri alıp çalıştırmayı öğreneceğiz.

# %%
import pandas as pd

# %%
df = pd.read_csv('hiring.csv')

# %%
df.head()
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000

# %%
import seaborn as sns

# %%
sns.countplot(x=df['experience'])
# Out:
# <Axes: xlabel='experience', ylabel='count'>

# %%
df.head()
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000

# %%
d={'two':2, 'three':3, 'five':5, 'seven':7, 'eight':8, 'ten':10, 'eleven':11}

# %%
df['experience']=df['experience'].map(d)

# %%
df['experience'] = df['experience'].fillna(0)

# %%
df.head()
# Out:
#    experience  test_score  interview_score  salary
# 0         0.0         8.0                9   50000
# 1         0.0         8.0                6   45000
# 2         5.0         6.0                7   60000
# 3         2.0        10.0               10   65000
# 4         7.0         9.0                6   70000

# %%
df.isnull().sum()
# Out:
# experience         0
# test_score         1
# interview_score    0
# salary             0
# dtype: int64

# %%
df['test_score'] = df['test_score'].fillna(df['test_score'].mean())

# %%
x=df.drop('salary', axis=1)
y=df[['salary']]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
model=lr.fit(x,y)

# %%
import pickle

# %%
pickle.dump(model, open('maas.pkl','wb'))

# %%
model.predict([[3,8,9]])
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[60796.51451437]])
